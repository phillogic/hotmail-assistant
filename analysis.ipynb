# %%
from utils.db_utils import init_db, close_db
import pandas as pd
import json

# %%
conn = init_db()
# Step 2: Query data from a specific table
table_name = "bronze_emails"  # Replace with the name of the table you want to view
query = f"SELECT * FROM {table_name}"

# Step 3: Load data into a DataFrame
df = pd.read_sql_query(query, conn)

# Step 4: Display the DataFrame
df["raw_data"][0]

# %%
# Step 2: Query data from a specific table
table_name = "silver_emails"  # Replace with the name of the table you want to view
query = f"SELECT * FROM {table_name}"

# Step 3: Load data into a DataFrame
df = pd.read_sql_query(query, conn)

#df.keys()
# Step 4: Display the DataFrame
